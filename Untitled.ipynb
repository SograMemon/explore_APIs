# %% [markdown]
# # Open Skills API

# %%
import pandas as pd
import json
import requests

# %%
url='http://api.dataatwork.org/v1/jobs/autocomplete?begins_with=Data'

# %%
results= requests.get(url).json()
results
# Out:
# [{'normalized_job_title': 'data operations director',
#   'parent_uuid': 'bb4e5066e69e4228172b4850d2a920f4',
#   'suggestion': 'Data Operations Director',
#   'uuid': '8fd068c8d9be73abfa678856177b6c40'},
#  {'normalized_job_title': 'data processing manager',
#   'parent_uuid': 'bb4e5066e69e4228172b4850d2a920f4',
#   'suggestion': 'Data Processing Manager',
#   'uuid': 'ac47656fd51c2cd8037057262c910dc4'},
#  {'normalized_job_title': 'data systems manager',
#   'parent_uuid': 'bb4e5066e69e4228172b4850d2a920f4',
#   'suggestion': 'Data Systems Manager',
#   'uuid': '800b621aab5dac18f4caef621fa43a49'},
#  {'normalized_job_title': 'database development and administration project manager',
#   'parent_uuid': 'bb4e5066e69e4228172b4850d2a920f4',
#   'suggestion': 'Database Development and Administration Project Manager',
#   'uuid': '3833bd699e7afe4665b595f282da0387'},
#  {'normalized_job_title': 'database designer',
#   'parent_uuid': '596226d5f9ef63de41a852826d483d19',
# ...

# %% [markdown]
# # Adzuna API

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

from pandas import DataFrame

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
#import json
#import requests
#from pandas.io.json import jason_normalize

# %%
# @hidden_cell'
API_ID = '260bbf3b' 
API_Key = '1ba8331c59a64b85cc9c18848f3ea7f2' 
job_Title= "Data"
#VERSION = '20180605' 
#print('Your credentails:')
#print('CLIENT_ID: ' + CLIENT_ID)
#print('CLIENT_SECRET:' + CLIENT_SECRET)

# %%
url= 'https://api.adzuna.com/v1/api/jobs/ca/search/1?app_id={}&app_key={}&title_only={}'.format(
    API_ID, 
    API_Key,
    job_Title)
url
# Out:
# 'https://api.adzuna.com/v1/api/jobs/ca/search/1?app_id=260bbf3b&app_key=1ba8331c59a64b85cc9c18848f3ea7f2&title_only=Data'

# %%
results = requests.get(url).json()["results"]
results
# Out:
# [{'__CLASS__': 'Adzuna::API::Response::Job',
#   'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTU2NTY5OTk2MCIsInMiOiJkamlSbzJtdDZoR25PbTl1N016ZWpRIn0.SeybnosB1IlREO2l6Ivz2BdGmLcFIlBIloAz-lN_COw',
#   'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#    'label': 'Unknown',
#    'tag': 'unknown'},
#   'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#    'display_name': 'Aquatic Informatics'},
#   'created': '2020-06-06T06:14:58Z',
#   'description': 'Do you want a meaningful role in a company that is making a difference in the world? Do you want to be involved in one of the most important environmental resource areas today? Do you want to learn what’s involved in developing and deploying machine learning and predictive analytics solutions from colleagues with years of research and development experience? Then join our energetic and growing team and help revolutionize an industry. About our company Founded in 2003, Aquatic Informatics provid…',
#   'id': '1565699960',
#   'latitude': 49.256582,
#   'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#    'area': ['Canada', 'British Columbia', 'Greater Vancouver'],
#    'display_name': 'Greater Vancouver, British Columbia'},
#   'longitude': -122.898456,
#   'redirect_url': 'https://www.adzuna.ca/land/ad/1565699960?se=djiRo2mt6hGnOm9u7MzejQ&utm_medium=api&utm_source=260bbf3b&v=B1F685A028D2BAEC4E2C9E8D067BC3EED2CBC5E2',
#   'salary_is_predicted': '0',
#   'title': '<strong>Data</strong> Scientist'},
#  {'__CLASS__': 'Adzuna::API::Response::Job',
#   'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTU2NTY5OTkxOCIsInMiOiJkamlSbzJtdDZoR25PbTl1N016ZWpRIn0.1dSuoPWuUluO1ut5IHvJDtjkJ0ptUJWDSWpfZ8ePeow',
#   'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#    'label': 'Scientific & QA Jobs',
#    'tag': 'scientific-qa-jobs'},
#   'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#    'display_name': 'IQVIA'},
#   'created': '2020-06-06T06:14:56Z',
#   'description': 'Job Description IQVIA™ is the leading human data science company focused on helping healthcare clients find unparalleled insights and better solutions for patients. Formed through the merger of IMS Health and Quintiles, IQVIA offers a broad range of solutions that harness the power of healthcare data, domain expertise, transformative technology, and advanced analytics to drive healthcare forward. Responsibilities: • Develop familiarity with our de-identification methodology. • Own assigned proj…',
#   'id': '1565699918',
#   'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#    'area': ['Canada', 'Ontario', 'Ottawa region', 'Ottawa'],
#    'display_name': 'Ottawa, Ottawa region'},
#   'redirect_url': 'https://www.adzuna.ca/land/ad/1565699918?se=djiRo2mt6hGnOm9u7MzejQ&utm_medium=api&utm_source=260bbf3b&v=940C087430AE558D6A42AA567FB69FF5CDE7653A',
#   'salary_is_predicted': '0',
#   'title': '<strong>Data</strong> Analyst'},
#  {'__CLASS__': 'Adzuna::API::Response::Job',
#   'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiZGppUm8ybXQ2aEduT205dTdNemVqUSIsImkiOiIxNTY1NzAxMjQ3In0.cKSyvhFSfz1K52h5CWOxUq3WUJK5CrBGdmRdu8URig4',
#   'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#    'label': 'Unknown',
#    'tag': 'unknown'},
#   'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#    'display_name': 'Electronic Arts'},
#   'created': '2020-06-06T06:15:33Z',
#   'description': 'Position Overview There are millions of FIFA players generating billions of events every day. We are using the high-volume data streams to detect and anticipate Security threats and issues as soon as they occur. The Game Security Engineer will be a key member of the FIFA Security Team. They will be tasked with supporting the Security Data Scientists by ensuring the availability of the data needed to perform big data analysis, machine learning and visualization to find patterns and correlations …',
#   'id': '1565701247',
#   'latitude': 49.256582,
#   'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#    'area': ['Canada', 'British Columbia', 'Greater Vancouver'],
#    'display_name': 'Greater Vancouver, British Columbia'},
#   'longitude': -122.898456,
#   'redirect_url': 'https://www.adzuna.ca/land/ad/1565701247?se=djiRo2mt6hGnOm9u7MzejQ&utm_medium=api&utm_source=260bbf3b&v=39D1C36953BBC6104696541508A23CC107377869',
#   'salary_is_predicted': '0',
#   'title': '<strong>Data</strong> Engineer'},
#  {'__CLASS__': 'Adzuna::API::Response::Job',
#   'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiZGppUm8ybXQ2aEduT205dTdNemVqUSIsImkiOiIxNTY1NzAwNzQ1In0.0CKGUhL0WALQEFBSvfOlhpFbfQzIbfIKYCE7mvsq620',
#   'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#    'label': 'Unknown',
#    'tag': 'unknown'},
#   'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#    'display_name': 'Replicon'},
#   'created': '2020-06-06T06:15:19Z',
#   'description': 'Replicon is looking to hire someone for our Time Intelligence platform who is passionate about taking data and transforming it into information and insights that can help our customers make the right decisions. Our SaaS application is used by thousands of customers, collecting data for millions of users, and we model business capabilities across many different industries. Objectives Work within our product engineering team to enhance our data analytics platform by identifying solutions to busin…',
#   'id': '1565700745',
#   'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#    'area': ['Canada', 'Alberta', 'Calgary region', 'Calgary'],
#    'display_name': 'Calgary, Calgary region'},
#   'redirect_url': 'https://www.adzuna.ca/land/ad/1565700745?se=djiRo2mt6hGnOm9u7MzejQ&utm_medium=api&utm_source=260bbf3b&v=09B5D0F08731FC386840568A240F7F02949A3AAC',
#   'salary_is_predicted': '0',
#   'title': '<strong>Data</strong> Scientist'},
#  {'__CLASS__': 'Adzuna::API::Response::Job',
#   'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTUzMzEwMjMwNCIsInMiOiJkamlSbzJtdDZoR25PbTl1N016ZWpRIn0.oy5ic-rnieLZ8Kud7hWsUqps5-jkg07oAOEEWPo4QrA',
#   'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#    'label': 'Unknown',
#    'tag': 'unknown'},
#   'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#    'display_name': 'Electronic Arts'},
#   'created': '2020-04-30T17:29:40Z',
#   'description': 'Data Engineer As a data engineer, you will report to our Sr Manager Data Science and will help develop and maintain the ETL solutions necessary to provide the data that powers our game analysis and reporting. We are looking for a data engineer to join our efforts in data science, machine learning, and R&D. You’ll be part of a central studio data science team, working with our data scientists and analysts to architect data pipelines, support machine learning research, and build feature prototype…',
#   'id': '1533102304',
#   'latitude': 49.256582,
#   'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#    'area': ['Canada', 'British Columbia', 'Greater Vancouver'],
#    'display_name': 'Greater Vancouver, British Columbia'},
#   'longitude': -122.898456,
#   'redirect_url': 'https://www.adzuna.ca/land/ad/1533102304?se=djiRo2mt6hGnOm9u7MzejQ&utm_medium=api&utm_source=260bbf3b&v=659CE7DACFA8DEE7C35972BE9E6D3D3819B3EE4B',
#   'salary_is_predicted': '0',
#   'title': '<strong>Data</strong> Engineer'},
#  {'__CLASS__': 'Adzuna::API::Response::Job',
#   'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTU2NjUyNTkyNyIsInMiOiJkamlSbzJtdDZoR25PbTl1N016ZWpRIn0.LlKOGN9Pd9f2TFrbM_V7sVhhglFb95-zRGiH933GDO8',
#   'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#    'label': 'IT Jobs',
#    'tag': 'it-jobs'},
#   'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#    'display_name': 'Procom'},
#   'created': '2020-06-07T06:27:36Z',
#   'description': 'Scientifique des données Dans le cadre de ses ententes avec ses différents clients, Procom est actuellement à la recherche d’un scientifique des données pour une entreprise dans le domaine bancaire. Notre client est situé à Montréal. Description des tâches et responsabilités — Scientifique des données En tant que scientifique principal des données, vous travaillerez au Centre d’excellence AI (AI CoE) et contribuerez aux meilleures pratiques, processus et plates-formes à l’échelle de l’entrepris…',
#   'id': '1566525927',
#   'latitude': 45.544959,
#   'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#    'area': ['Canada', 'Québec', 'Montréal'],
#    'display_name': 'Montréal, Québec'},
#   'longitude': -73.588138,
#   'redirect_url': 'https://www.adzuna.ca/land/ad/1566525927?se=djiRo2mt6hGnOm9u7MzejQ&utm_medium=api&utm_source=260bbf3b&v=412353F0A5B062C900A2DE2A6D812F86CA671CDF',
#   'salary_is_predicted': '0',
#   'title': '<strong>Data</strong> Scientist'},
#  {'__CLASS__': 'Adzuna::API::Response::Job',
#   'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiZGppUm8ybXQ2aEduT205dTdNemVqUSIsImkiOiIxNTYxNDQ2NTIwIn0.qjLQZXBXJ_GcMAVYQSHxJs28p0KNDQgrs6iHCwbF1oY',
#   'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#    'label': 'Unknown',
#    'tag': 'unknown'},
#   'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#    'display_name': 'Robert Half Canada'},
#   'created': '2020-06-02T06:01:27Z',
#   'description': "Ref ID: 05060-9502584122 Classification: Data Engineer Compensation: $70000.00 to $90000.00 yearly [ POSITION DETAILS / JOB TITLE / LEVEL OF SENIORITY] In this Data Engineer role, you'll be taking responsibility to look after the data management at the company by working closely with the architect/dev team. The core part of your duty will include data collection, analysis, and data system management. [ BENEFITS / PERKS / COMPENSATION] In this full-time position, you'll earn a competitive base s…",
#   'id': '1561446520',
#   'latitude': 49.24792,
#   'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#    'area': ['Canada',
#     'British Columbia',
#     'Greater Vancouver',
#     'Vancouver',
#     'Renfrew-Collingwood'],
#    'display_name': 'Renfrew-Collingwood, Vancouver'},
#   'longitude': -123.00824,
#   'redirect_url': 'https://www.adzuna.ca/land/ad/1561446520?se=djiRo2mt6hGnOm9u7MzejQ&utm_medium=api&utm_source=260bbf3b&v=31D79BE1DF6B3F4541FF1624481DC6FAF4899060',
#   'salary_is_predicted': '0',
#   'title': '<strong>Data</strong> Engineer'},
#  {'__CLASS__': 'Adzuna::API::Response::Job',
#   'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTU0OTU2NTI5MCIsInMiOiJkamlSbzJtdDZoR25PbTl1N016ZWpRIn0.9lEcwzgMZca1qDEKHM5tcLT9a8sOkE7SYzHixJsFUQE',
#   'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#    'label': 'IT Jobs',
#    'tag': 'it-jobs'},
#   'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#    'display_name': 'Procom'},
#   'created': '2020-05-20T05:33:48Z',
#   'description': 'On behalf of our client in Edmonton, Procom is searching for a Senior Data Architect to fulfill a one year contract. Senior Data Architect Responsible for providing leadership and design initiatives for data architecture in the design and configuration of SAP Cloud Solutions Develops data architecture and integration to support the ERP migration from on-premise systems to SAP Cloud Solutions Maps data flows through the organization to determine the best path forward for data migration strategy …',
#   'id': '1549565290',
#   'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#    'area': ['Canada', 'Alberta', 'Edmonton region', 'Edmonton'],
#    'display_name': 'Edmonton, Edmonton region'},
#   'redirect_url': 'https://www.adzuna.ca/land/ad/1549565290?se=djiRo2mt6hGnOm9u7MzejQ&utm_medium=api&utm_source=260bbf3b&v=AE8615632333FED08886817C84C78AC9FB3B988B',
#   'salary_is_predicted': '0',
#   'title': '<strong>Data</strong> Architect'},
#  {'__CLASS__': 'Adzuna::API::Response::Job',
#   'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiZGppUm8ybXQ2aEduT205dTdNemVqUSIsImkiOiIxNTUyMTMxNDQ3In0.x1-q8ekd0eC7d6tYOUmL0P2d-aJVuWnNPJF-uOodB4E',
#   'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#    'label': 'IT Jobs',
#    'tag': 'it-jobs'},
#   'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#    'display_name': 'Canadian Forces Recruiting Centre'},
#   'contract_type': 'permanent',
#   'created': '2020-05-22T17:48:29Z',
#   'description': "JOB DESCRIPTION:  Please note that the trade of Data administrator corresponds to the trade of Communicator research operators in the Canadian Armed Forces.  By applying for this job offer, you are applying for a MILITARY JOB. Communicator research operators intercept and analyze electronic transmissions, including foreign communications. They also protect Government of Canada's computer networks. Their primary duties are to collect, process, analyze and report on electromagnetic activity on ra…",
#   'id': '1552131447',
#   'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#    'area': ['Canada', 'Québec', 'Laval region', 'Laval'],
#    'display_name': 'Laval, Laval region'},
#   'redirect_url': 'https://www.adzuna.ca/land/ad/1552131447?se=djiRo2mt6hGnOm9u7MzejQ&utm_medium=api&utm_source=260bbf3b&v=5878C3C7C90D0E5BE6C1E09B2600C79D28B933F5',
#   'salary_is_predicted': '0',
#   'title': '<strong>Data</strong> administrator'},
#  {'__CLASS__': 'Adzuna::API::Response::Job',
#   'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTU1MTIwODc1MyIsInMiOiJkamlSbzJtdDZoR25PbTl1N016ZWpRIn0.QZrg5pyFJn3t1MYFgjH-V5GS0Yc95P-1aN0_62mTHRs',
#   'category': {'__CLASS__': 'Adzuna::API::Response::Category',
#    'label': 'IT Jobs',
#    'tag': 'it-jobs'},
#   'company': {'__CLASS__': 'Adzuna::API::Response::Company',
#    'display_name': 'Canadian Forces Recruiting Centre'},
#   'contract_type': 'permanent',
#   'created': '2020-05-21T17:49:26Z',
#   'description': "JOB DESCRIPTION:  Please note that the trade of Data administrator corresponds to the trade of Communicator research operators in the Canadian Armed Forces.  By applying for this job offer, you are applying for a MILITARY JOB. Communicator research operators intercept and analyze electronic transmissions, including foreign communications. They also protect Government of Canada's computer networks. Their primary duties are to collect, process, analyze and report on electromagnetic activity on ra…",
#   'id': '1551208753',
#   'latitude': 45.544959,
#   'location': {'__CLASS__': 'Adzuna::API::Response::Location',
#    'area': ['Canada', 'Québec', 'Montréal'],
#    'display_name': 'Montréal, Québec'},
#   'longitude': -73.588138,
#   'redirect_url': 'https://www.adzuna.ca/land/ad/1551208753?se=djiRo2mt6hGnOm9u7MzejQ&utm_medium=api&utm_source=260bbf3b&v=022DF5B84FF1E2B63BCF4162D13B42C055C3E1C8',
#   'salary_is_predicted': '0',
#   'title': '<strong>Data</strong> administrator'}]

# %%
df= pd.DataFrame(results)
df.head()
# Out:
#                                                adref          id  \
# 0  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTU2NTY5OTk2MCIsI...  1565699960
# 1  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTU2NTY5OTkxOCIsI...  1565699918
# 2  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiZGppUm8ybXQ2aEduT...  1565701247
# 3  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiZGppUm8ybXQ2aEduT...  1565700745
# 4  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiMTUzMzEwMjMwNCIsI...  1533102304
#
#   salary_is_predicted   longitude   latitude                            title  \
# 0                   0 -122.898456  49.256582  <strong>Data</strong> Scientist
# 1                   0         NaN        NaN    <strong>Data</strong> Analyst
# 2                   0 -122.898456  49.256582   <strong>Data</strong> Engineer
# 3                   0         NaN        NaN  <strong>Data</strong> Scientist
# 4                   0 -122.898456  49.256582   <strong>Data</strong> Engineer
#
#                                             location  \
# 0  {'__CLASS__': 'Adzuna::API::Response::Location...
# 1  {'__CLASS__': 'Adzuna::API::Response::Location...
# 2  {'__CLASS__': 'Adzuna::API::Response::Location...
# 3  {'__CLASS__': 'Adzuna::API::Response::Location...
# 4  {'__CLASS__': 'Adzuna::API::Response::Location...
#
#                                             category  \
# 0  {'tag': 'unknown', '__CLASS__': 'Adzuna::API::...
# 1  {'tag': 'scientific-qa-jobs', '__CLASS__': 'Ad...
# 2  {'tag': 'unknown', 'label': 'Unknown', '__CLAS...
# 3  {'tag': 'unknown', '__CLASS__': 'Adzuna::API::...
# 4  {'tag': 'unknown', '__CLASS__': 'Adzuna::API::...
#
#                     __CLASS__  \
# 0  Adzuna::API::Response::Job
# 1  Adzuna::API::Response::Job
# 2  Adzuna::API::Response::Job
# 3  Adzuna::API::Response::Job
# 4  Adzuna::API::Response::Job
#
#                                          description  \
# 0  Do you want a meaningful role in a company tha...
# 1  Job Description IQVIA™ is the leading human da...
# 2  Position Overview There are millions of FIFA p...
# 3  Replicon is looking to hire someone for our Ti...
# 4  Data Engineer As a data engineer, you will rep...
#
#                                         redirect_url  \
# 0  https://www.adzuna.ca/land/ad/1565699960?se=dj...
# 1  https://www.adzuna.ca/land/ad/1565699918?se=dj...
# 2  https://www.adzuna.ca/land/ad/1565701247?se=dj...
# 3  https://www.adzuna.ca/land/ad/1565700745?se=dj...
# 4  https://www.adzuna.ca/land/ad/1533102304?se=dj...
#
#                                              company               created  \
# 0  {'__CLASS__': 'Adzuna::API::Response::Company'...  2020-06-06T06:14:58Z
# 1  {'__CLASS__': 'Adzuna::API::Response::Company'...  2020-06-06T06:14:56Z
# 2  {'__CLASS__': 'Adzuna::API::Response::Company'...  2020-06-06T06:15:33Z
# 3  {'__CLASS__': 'Adzuna::API::Response::Company'...  2020-06-06T06:15:19Z
# 4  {'__CLASS__': 'Adzuna::API::Response::Company'...  2020-04-30T17:29:40Z
#
#   contract_type
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df.shape
# Out:
# (10, 14)
